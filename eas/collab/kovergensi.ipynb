# %%
# !pip install matplotlib
# Out:
# zsh:1: /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/bin/pip: bad interpreter: /Users/nailahqonitahfirdausa/midtermproject/sc-midterm/.venv/bin/python3.12: no such file or directory

# %%
import sys
!"{sys.executable}" -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/nailahqonitahfirdausa/SEM 6/scprojects/finalproject/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import json
import os

# 1. Setup Path & Nama File
path_json = '../output_json'
file_mapping = {
    'ACO': 'rute_aco.json',
    'DPSO': 'rute_dpso.json',
    'GA': 'rute_ga.json',
    'MA': 'rute_ma.json'
}

# 2. Load Semua Data JSON
data_all = {}
for algo, filename in file_mapping.items():
    filepath = os.path.join(path_json, filename)
    if os.path.exists(filepath):
        with open(filepath, 'r') as f:
            data_all[algo] = json.load(f)
    else:
        print(f"⚠️ Peringatan: {filename} belum ada di folder!")

# 3. Setup Kanvas Grafik (3 Baris x 2 Kolom)
klaster_list = ['Barat', 'Pusat', 'Selatan', 'Timur', 'Utara']
warna_algo = {'ACO': '#1f77b4', 'DPSO': '#d62728', 'GA': '#ff7f0e', 'MA': '#2ca02c'} 

fig, axes = plt.subplots(3, 2, figsize=(16, 14))
fig.suptitle('Perbandingan Konvergensi Algoritma Metaheuristik (Total Jarak KM)', fontsize=18, fontweight='bold', y=0.98)
axes = axes.flatten()

# 4. Plotting untuk setiap Klaster
for idx, klaster in enumerate(klaster_list):
    ax = axes[idx]
    
    for algo, data in data_all.items():
        klaster_key = klaster if klaster in data['hasil_per_klaster'] else klaster.capitalize()
        
        if klaster_key in data['hasil_per_klaster']:
            # PAKE .get() BIAR AMAN DARI KEYERROR
            riwayat = data['hasil_per_klaster'][klaster_key].get('riwayat_konvergensi')
            
            # Kalau datanya ada, baru di-plot
            if riwayat and isinstance(riwayat, list):
                ax.plot(range(1, len(riwayat) + 1), riwayat, label=algo, color=warna_algo.get(algo), linewidth=2.5, alpha=0.8)
            else:
                print(f"⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma {algo} di klaster {klaster_key}.")
    
    # Percantik tiap grafik
    ax.set_title(f'Klaster {klaster}', fontsize=14, fontweight='bold')
    ax.set_xlabel('Generasi / Iterasi', fontsize=11)
    ax.set_ylabel('Jarak Tempuh (KM)', fontsize=11)
    ax.grid(True, linestyle='--', alpha=0.6)
    
    # Supaya legend cuma muncul kalau ada garis yang digambar
    handles, labels = ax.get_legend_handles_labels()
    if handles:
        ax.legend(title='Algoritma')

# Sembunyikan subplot ke-6 yang kosong
axes[-1].axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.92)

# Simpan grafiknya jadi gambar kualitas tinggi
file_gambar = '../output_json/grafik_konvergensi_all.png'
plt.savefig(file_gambar, dpi=300, bbox_inches='tight')
print(f"✅ Grafik berhasil dibuat dan disimpan di: {file_gambar}")

plt.show()
# Out:
# ✅ Grafik berhasil dibuat dan disimpan di: ../output_json/grafik_konvergensi_all.png

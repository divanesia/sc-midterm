# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\shahnaz ariqah\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import sys
!"{sys.executable}" -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\shahnaz ariqah\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\shahnaz ariqah\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shahnaz ariqah\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shahnaz ariqah\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    --------------- ------------------------ 3.7/9.3 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 20.1 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 15.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    -------------------------- ------------- 4.7/7.1 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 21.4 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.2.0 pyparsing-3.3.2
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import json
import os

# 1. Setup Path & Nama File
path_json = '../output_json'
file_mapping = {
    'ACO': 'rute_aco.json',
    'DPSO': 'rute_dpso.json',
    'GA': 'rute_ga.json',
    'MA': 'rute_ma.json'
}

# 2. Load Semua Data JSON
data_all = {}
for algo, filename in file_mapping.items():
    filepath = os.path.join(path_json, filename)
    if os.path.exists(filepath):
        with open(filepath, 'r') as f:
            data_all[algo] = json.load(f)
    else:
        print(f"⚠️ Peringatan: {filename} belum ada di folder!")

# 3. Setup Kanvas Grafik (3 Baris x 2 Kolom)
klaster_list = ['Barat', 'Pusat', 'Selatan', 'Timur', 'Utara']
warna_algo = {'ACO': '#1f77b4', 'DPSO': '#d62728', 'GA': '#ff7f0e', 'MA': '#2ca02c'} 

fig, axes = plt.subplots(3, 2, figsize=(16, 14))
fig.suptitle('Perbandingan Konvergensi Algoritma Metaheuristik (Total Jarak KM)', fontsize=18, fontweight='bold', y=0.98)
axes = axes.flatten()

# 4. Plotting untuk setiap Klaster
for idx, klaster in enumerate(klaster_list):
    ax = axes[idx]
    
    for algo, data in data_all.items():
        klaster_key = klaster if klaster in data['hasil_per_klaster'] else klaster.capitalize()
        
        if klaster_key in data['hasil_per_klaster']:
            # PAKE .get() BIAR AMAN DARI KEYERROR
            riwayat = data['hasil_per_klaster'][klaster_key].get('riwayat_konvergensi')
            
            # Kalau datanya ada, baru di-plot
            if riwayat and isinstance(riwayat, list):
                ax.plot(range(1, len(riwayat) + 1), riwayat, label=algo, color=warna_algo.get(algo), linewidth=2.5, alpha=0.8)
            else:
                print(f"⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma {algo} di klaster {klaster_key}.")
    
    # Percantik tiap grafik
    ax.set_title(f'Klaster {klaster}', fontsize=14, fontweight='bold')
    ax.set_xlabel('Generasi / Iterasi', fontsize=11)
    ax.set_ylabel('Jarak Tempuh (KM)', fontsize=11)
    ax.grid(True, linestyle='--', alpha=0.6)
    
    # Supaya legend cuma muncul kalau ada garis yang digambar
    handles, labels = ax.get_legend_handles_labels()
    if handles:
        ax.legend(title='Algoritma')

# Sembunyikan subplot ke-6 yang kosong
axes[-1].axis('off')

plt.tight_layout()
plt.subplots_adjust(top=0.92)

# Simpan grafiknya jadi gambar kualitas tinggi
file_gambar = '../output_json/grafik_konvergensi_all.png'
plt.savefig(file_gambar, dpi=300, bbox_inches='tight')
print(f"✅ Grafik berhasil dibuat dan disimpan di: {file_gambar}")

plt.show()
# Out:
# ⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma DPSO di klaster Barat.
# ⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma DPSO di klaster Pusat.
# ⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma DPSO di klaster Selatan.
# ⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma DPSO di klaster Timur.
# ⚠️ Info: Data riwayat_konvergensi tidak ditemukan untuk algoritma DPSO di klaster Utara.
# ✅ Grafik berhasil dibuat dan disimpan di: ../output_json/grafik_konvergensi_all.png
